# %% [markdown]
# <a href="https://colab.research.google.com/github/tongnet/FIN4014_2026fall/blob/main/fin4014_lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the numpy_financial package
# !pip install numpy-financial
import numpy_financial as npf

# Calculate the bond price
p_bond = -npf.pv(0.09/2, 10*2, 40, 1000, 0)

# Print out the result
print(f"the bond price is ${p_bond}")
